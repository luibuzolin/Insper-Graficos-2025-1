# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
plt.title("Meu Gráfico de Teste")
plt.show()
